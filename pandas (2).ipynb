# %%
#PANDAS
# !pip install pandas

# %%
# !pip install numpy

# %%
"""data frame
#qualitative data - , quantitative data - numerical data
#python is interpreter , java is compiler
#pandas (data manipulation and analysis , for processing the data) . build from numpy.
#for processing the large data go for 'polars'
#data preprocessing
roboflow provides -data anatation(analysis) - data collection-> organise->label->process->train->model->deploy
search about the algo for training domine(DS)

PANDAS:
SERIES - 1D (sequence , ordered , )
DATAFRAMES - 2D(rows and columns)
D/B numpy & pandas : 20:80 usage of numpy(20% lib & 80% application of that func)
pandas - through row and col we can access data.
co lab runtime TPU -tensor process unit, CPU , GPU-  (parllelisim)
""""""

# %%
import pandas as pd
import numpy as np
a=np.array([1,2,3,4,5])
#print(a[2])
s=pd.Series([10,11,22,33,44,55])
print(s)
print(s.drop(3))
print(s[3])
s.drop(3,inplace=True)
print(s)
# Out:
# 0    10
# 1    11
# 2    22
# 3    33
# 4    44
# 5    55
# dtype: int64
# 0    10
# 1    11
# 2    22
# 4    44
# 5    55
# dtype: int64
# 33
# 0    10
# 1    11
# 2    22
# 4    44
# 5    55
# dtype: int64

# %%
s.iloc[3]
# Out:
# 44

# %%
s.loc[4]
# Out:
# 44

# %%
s.index
# Out:
# Int64Index([0, 1, 2, 4, 5], dtype='int64')

# %%
i=pd.Series([10,11,22,33,44,55],index=['a','b','c','d','e','d'])
print(i)
print(i.loc['d'])
print(i.iloc['c'])
# Out:
# a    10
# b    11
# c    22
# d    33
# e    44
# d    55
# dtype: int64
# d    33
# d    55
# dtype: int64
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-cc46f45565ac> in <cell line: 4>()
#       2 print(i)
#       3 print(i.loc['d'])
# ----> 4 print(i.iloc['c'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1071
#    1072             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073             return self._getitem_axis(maybe_callable, axis=axis)
#    1074
#    1075     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1620             key = item_from_zerodim(key)
#    1621             if not is_integer(key):
# ...

# %%
data = [['alex',10,'2323'],['bob',None,None],['sis',None,'2320']]
print(data)
# Out:
# [['alex', 10, '2323'], ['bob', None, None], ['sis', None, '2320']]

# %%
#df=pd.DataFrame(data,index=['name','age','dob'],columns=['name','age','dob'])
df=pd.DataFrame(data)
print(df)
#print(df['name']['dob'])
print(df[1:2])#entire value of bob
df=pd.DataFrame(data,columns=['name','age','dob'])
print('\n')
print(df)
print('\n')
print(df['name'])
#print(df[[0,2]])#prints 0 to 1 column values
print('\n')
print(df['name'][0])
print('\n')
print(df.loc[0,'name'])
print('\n')
print(df[0:1])
print('\n')
print(df[0:2])
# Out:
#       0     1     2
# 0  alex  10.0  2323
# 1   bob   NaN  None
# 2   sis   NaN  2320
#      0   1     2
# 1  bob NaN  None
#
#
#    name   age   dob
# 0  alex  10.0  2323
# 1   bob   NaN  None
# 2   sis   NaN  2320
#
#
# 0    alex
# 1     bob
# 2     sis
# Name: name, dtype: object
#
#
# alex
#
#
# alex
#
#
#    name   age   dob
# 0  alex  10.0  2323
#
#
#    name   age   dob
# 0  alex  10.0  2323
# 1   bob   NaN  None

# %%
s=pd.Series([1,2,3,4])
print(s)
print(s.plot())
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
# Axes(0.125,0.11;0.775x0.77)

# %%
s.hist(bins=2)
# Out:
# <Axes: >

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
ss=s.to_numpy()

# %%
type(ss)
# Out:
# numpy.ndarray

# %%
df
# Out:
#    name   age   dob
# 0  alex  10.0  2323
# 1   bob   NaN  None
# 2   sis   NaN  2320

# %%
df.head(1)
# Out:
#    name   age   dob
# 0  alex  10.0  2323

# %%
df.tail(-2)
# Out:
#   name  age   dob
# 2  sis  NaN  2320

# %%
#None ,' ','' , '-' , '?' , 'Nil' , np.nan

# %%
df
# Out:
#    name   age   dob
# 0  alex  10.0  2323
# 1   bob   NaN  None
# 2   sis   NaN  2320

# %%
df.isnull().sum()
# Out:
# name    0
# age     2
# dob     1
# dtype: int64

# %%
df.dropna()#entire NaN value will be removed
# Out:
#    name   age   dob
# 0  alex  10.0  2323

# %%
df
# Out:
#    name   age   dob
# 0  alex  10.0  2323
# 1   bob   NaN  None
# 2   sis   NaN  2320

# %%
df
# Out:
#    name   dob
# 0  alex  2323

# %%
#df.drop(['age'],axis=1,inplace=True)

# %%
data = [['alex',10,'2323'],['bob',None,None],['sis',None,'2320']]
df=pd.DataFrame(data,columns=['name','age','dob'])
df
# Out:
#    name   age   dob
# 0  alex  10.0  2323
# 1   bob   NaN  None
# 2   sis   NaN  2320

# %%
df.drop([0,2])
# Out:
#   name  age   dob
# 1  bob  NaN  None

# %%
a=np.array([1,2,3,4,5])
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
a>2
# Out:
# array([False, False,  True,  True,  True])

# %%
a[a%2!=0]
# Out:
# array([1, 3, 5])

# %%
df
# Out:
#    name   age   dob
# 0  alex  10.0  2323
# 1   bob   NaN  None
# 2   sis   NaN  2320

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   age     1 non-null      float64
#  2   dob     2 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 200.0+ bytes

# %%
df['name'].str.contains('e')
#df['name'].str.contains('b')
# Out:
# 0     True
# 1    False
# 2    False
# Name: name, dtype: bool

# %%
df
# Out:
#    name   age   dob
# 0  alex  10.0  2323
# 1   bob   NaN  None
# 2   sis   NaN  2320

# %%
print(df.shape)
print(df.size)
print(df.axes)
print(df.ndim)
print(df.dtypes)
print(df.index )
print(df.columns)
print(df.values)
# Out:
# (3, 3)
# 9
# [RangeIndex(start=0, stop=3, step=1), Index(['name', 'age', 'dob'], dtype='object')]
# 2
# name     object
# age     float64
# dob      object
# dtype: object
# RangeIndex(start=0, stop=3, step=1)
# Index(['name', 'age', 'dob'], dtype='object')
# [['alex' 10.0 '2323']
#  ['bob' nan None]
#  ['sis' nan '2320']]

# %%
df.head()
# Out:
#    name   age   dob
# 0  alex  10.0  2323
# 1   bob   NaN  None
# 2   sis   NaN  2320

# %%
df2=pd.concat([df,df])
df2
# Out:
#    name   age   dob
# 0  alex  10.0  2323
# 1   bob   NaN  None
# 2   sis   NaN  2320
# 0  alex  10.0  2323
# 1   bob   NaN  None
# 2   sis   NaN  2320

# %%
df['name']
# Out:
# 0    alex
# 1     bob
# 2     sis
# Name: name, dtype: object

# %%
df.dob
# Out:
# 0    2323
# 1    None
# 2    2320
# Name: dob, dtype: object

# %%
df[['name','age']]
# Out:
#    name   age
# 0  alex  10.0
# 1   bob   NaN
# 2   sis   NaN

# %%
df.loc[0][1]
# Out:
# '2323'

# %%
df.iloc[1,0]
# Out:
# 'bob'

# %%
df.loc[0,'name']
# Out:
# 'alex'

# %%
#reading from file
""" csv , JSON, excel, SQL queries,HTML,TSV"""

# %%
import pandas as pd
df=pd.read_html("https://en.wikipedia.org/wiki/List_of_highest-grossing_films")
df
# Out:
# [    Rank  Peak                                          Title  \
#  0      1     1                                         Avatar
#  1      2     1                              Avengers: Endgame
#  2      3     3                       Avatar: The Way of Water
#  3      4     1                                        Titanic
#  4      5     3                   Star Wars: The Force Awakens
#  5      6     4                         Avengers: Infinity War
#  6      7     6                        Spider-Man: No Way Home
#  7      8     3                                 Jurassic World
#  8      9     7                                  The Lion King
#  9     10     3                                   The Avengers
#  10    11     4                                      Furious 7
#  11    12    11                              Top Gun: Maverick
#  12    13    10                                      Frozen II
#  13    14    14                                       Barbie †
# ...

# %%
type(df)
# Out:
# list

# %%
df=pd.read_table("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/chipotle.tsv")
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
type(df.item_name)
# Out:
# pandas.core.series.Series

# %%
df.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
df.item_price = df.item_price.str.replace('$','')
df.head(10)
# Out:
# <ipython-input-15-b926718db947>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.item_price = df.item_price.str.replace('$','')
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
# ...

# %%
df.item_price = df.item_price.astype(float)

# %%
type(df.item_price[0])
# Out:
# numpy.float64

# %%
df.item_name.unique
# Out:
# <bound method Series.unique of 0                Chips and Fresh Tomato Salsa
# 1                                        Izze
# 2                            Nantucket Nectar
# 3       Chips and Tomatillo-Green Chili Salsa
# 4                                Chicken Bowl
#                         ...
# 4617                            Steak Burrito
# 4618                            Steak Burrito
# 4619                       Chicken Salad Bowl
# 4620                       Chicken Salad Bowl
# 4621                       Chicken Salad Bowl
# Name: item_name, Length: 4622, dtype: object>

# %%
df_drink = df[df.item_price<1.1]

# %%
df_drink.item_name.unique()
#df_drink.item_name.nunique()
#df_drink.item_name.value_counts()
# Out:
# array(['Canned Soda', 'Bottled Water'], dtype=object)

# %%
df[df.item_name=='Chicken Bowl']
# Out:
#       order_id  quantity     item_name  \
# 4            2         2  Chicken Bowl
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# ...        ...       ...           ...
# 4590      1825         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# ...                                                 ...         ...
# ...

# %%
df[df.item_name=='Steak Burrito'].choice_description.nunique()
# Out:
# 251

# %%
df.dropna(inplace=True)

# %%
df[df.choice_description.str.contains('Black Beans')].item_name.value_counts()
# Out:
# Chicken Bowl             386
# Chicken Burrito          282
# Steak Burrito            148
# Steak Bowl               110
# Veggie Bowl               60
# Veggie Burrito            55
# Chicken Salad Bowl        49
# Carnitas Bowl             39
# Barbacoa Bowl             37
# Barbacoa Burrito          30
# Carnitas Burrito          28
# Chicken Soft Tacos        19
# Chicken Crispy Tacos      14
# Veggie Salad Bowl         13
# Steak Salad Bowl          13
# Steak Soft Tacos          10
# Carnitas Soft Tacos        7
# Chicken Salad              7
# Veggie Soft Tacos          6
# Barbacoa Soft Tacos        6
# Veggie Salad               5
# Barbacoa Salad Bowl        4
# Barbacoa Crispy Tacos      3
# Carnitas Crispy Tacos      3
# Carnitas Salad Bowl        3
# Steak Crispy Tacos         2
# Steak Salad                2
# Salad                      2
# Burrito                    1
# Carnitas Salad             1
# Name: item_name, dtype: int64

# %%
df[(df.item_price<10)&(df.item_name=='Chicken Bowl')]
# Out:
#       order_id  quantity     item_name  \
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# 76          34         1  Chicken Bowl
# 78          34         1  Chicken Bowl
# 99          44         1  Chicken Bowl
# ...        ...       ...           ...
# 4583      1823         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# 76    [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...        8.75
# 78    [Fresh Tomato Salsa, [Rice, Black Beans, Chees...        8.75
# 99    [Tomatillo Red Chili Salsa, [Rice, Fajita Vege...        8.75
# ...                                                 ...         ...
# ...

# %%
df[(df.item_price<10)&(df.item_name=='Chicken Bowl')].sort_values(['item_price'])
# Out:
#       order_id  quantity     item_name  \
# 3664      1466         1  Chicken Bowl
# 2918      1160         1  Chicken Bowl
# 3101      1237         1  Chicken Bowl
# 3396      1362         1  Chicken Bowl
# 1645       665         1  Chicken Bowl
# ...        ...       ...           ...
# 1876       759         1  Chicken Bowl
# 1852       751         1  Chicken Bowl
# 1851       750         1  Chicken Bowl
# 1829       740         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 3664  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 2918  [Fresh Tomato (Mild), [Rice, Sour Cream, Cheese]]        8.19
# 3101  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 3396  [Tomatillo-Green Chili Salsa (Medium), [Pinto ...        8.49
# 1645  [[Fresh Tomato Salsa (Mild), Tomatillo-Red Chi...        8.49
# ...                                                 ...         ...
# ...

# %%
movies = pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/imdb_1000.csv")
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies[(movies.star_rating>=8)&(movies.genre=='Action')].sort_values(['duration'])
# Out:
#      star_rating                                           title  \
# 276          8.1                            A Fistful of Dollars
# 327          8.0                    The Adventures of Robin Hood
# 235          8.1                                         Yip Man
# 281          8.1                                  The Terminator
# 123          8.3                                     The General
# 96           8.4                                         Yojimbo
# 198          8.1                               Kill Bill: Vol. 1
# 349          8.0                                      District 9
# 391          8.0                                Edge of Tomorrow
# 239          8.1                   Elite Squad: The Enemy Within
# 37           8.6                         Raiders of the Lost Ark
# 261          8.1                                     Elite Squad
# 240          8.1                            The Bourne Ultimatum
# ...

# %%
movies[movies.actors_list]

# %%
movies[movies.actors_list.str.contains('Leonardo DiCaprio')]
# Out:
#      star_rating                        title content_rating      genre  \
# 11           8.8                    Inception          PG-13     Action
# 49           8.5                 The Departed              R      Crime
# 59           8.5             Django Unchained              R    Western
# 143          8.2      The Wolf of Wall Street              R  Biography
# 244          8.1               Shutter Island              R    Mystery
# 309          8.0                Blood Diamond              R  Adventure
# 340          8.0          Catch Me If You Can          PG-13  Biography
# 562          7.8  What's Eating Gilbert Grape          PG-13      Drama
# 620          7.7                      Titanic          PG-13      Drama
# 828          7.5            Gangs of New York              R      Crime
# 888          7.5                  The Aviator          PG-13  Biography
#
#      duration                                        actors_list
# ...

# %%
movies[movies.actors_list.str.contains('Leonardo DiCaprio')].sort_values(['duration'])
# Out:
#      star_rating                        title content_rating      genre  \
# 562          7.8  What's Eating Gilbert Grape          PG-13      Drama
# 244          8.1               Shutter Island              R    Mystery
# 340          8.0          Catch Me If You Can          PG-13  Biography
# 309          8.0                Blood Diamond              R  Adventure
# 11           8.8                    Inception          PG-13     Action
# 49           8.5                 The Departed              R      Crime
# 59           8.5             Django Unchained              R    Western
# 828          7.5            Gangs of New York              R      Crime
# 888          7.5                  The Aviator          PG-13  Biography
# 143          8.2      The Wolf of Wall Street              R  Biography
# 620          7.7                      Titanic          PG-13      Drama
#
#      duration                                        actors_list
# ...

# %%
movies[movies.actors_list.str.contains('Leonardo DiCaprio')].sort_values(['star_rating','duration'],ascending=(False,True))
# Out:
#      star_rating                        title content_rating      genre  \
# 11           8.8                    Inception          PG-13     Action
# 49           8.5                 The Departed              R      Crime
# 59           8.5             Django Unchained              R    Western
# 143          8.2      The Wolf of Wall Street              R  Biography
# 244          8.1               Shutter Island              R    Mystery
# 340          8.0          Catch Me If You Can          PG-13  Biography
# 309          8.0                Blood Diamond              R  Adventure
# 562          7.8  What's Eating Gilbert Grape          PG-13      Drama
# 620          7.7                      Titanic          PG-13      Drama
# 828          7.5            Gangs of New York              R      Crime
# 888          7.5                  The Aviator          PG-13  Biography
#
#      duration                                        actors_list
# ...

# %%
ufo = pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/ufo.csv")
ufo
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
ufo.dropna(subset=['City','Shape Reported'],how='any').shape
# Out:
# (15576, 5)

# %%
ufo.dropna(subset=['City','Shape Reported'],how='all').shape
# Out:
# (18237, 5)

# %%
ufo['Shape Reported'].isnull().sum()
# Out:
# 2644

# %%
ufo['Shape Reported'].value_counts()
# Out:
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# DOME            1
# PYRAMID         1
# FLARE           1
# HEXAGON         1
# Name: Shape Reported, dtype: int64

# %%
drinks = pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/drinks.csv")
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
drinks.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
drinks.beer_servings.min()
# Out:
# 0

# %%
drinks.beer_servings.max()
# Out:
# 376

# %%
drinks[drinks.continent == 'Asia'].describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count      44.000000        44.000000      44.000000
# mean       37.045455        60.840909       9.068182
# std        49.469725        84.362160      21.667034
# min         0.000000         0.000000       0.000000
# 25%         4.250000         1.000000       0.000000
# 50%        17.500000        16.000000       1.000000
# 75%        60.500000        98.000000       8.000000
# max       247.000000       326.000000     123.000000
#
#        total_litres_of_pure_alcohol
# count                     44.000000
# mean                       2.170455
# std                        2.770239
# min                        0.000000
# 25%                        0.100000
# 50%                        1.200000
# 75%                        2.425000
# max                       11.500000

# %%
drinks[drinks.continent == 'Asia'].beer_servings.agg(['mean','min','max'])
# Out:
# mean     37.045455
# min       0.000000
# max     247.000000
# Name: beer_servings, dtype: float64

# %%
drinks.groupby('continent').beer_servings.max()
# Out:
# continent
# Africa           376
# Asia             247
# Europe           361
# North America    285
# Oceania          306
# South America    333
# Name: beer_servings, dtype: int64

# %%
drinks.groupby('continent').beer_servings.agg(['mean','min','max'])
# Out:
#                      mean  min  max
# continent
# Africa          61.471698    0  376
# Asia            37.045455    0  247
# Europe         193.777778    0  361
# North America  145.434783    1  285
# Oceania         89.687500    0  306
# South America  175.083333   93  333
